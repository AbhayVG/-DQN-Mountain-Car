# %% [markdown]
# # Import Libraries
#
# gymnasium: Library for creating and interacting with environments.
#
# numpy: For numerical operations.
#
# torch: PyTorch library for building and training neural networks.
#
# random: To ensure randomness.
#
# deque: A double-ended queue to store experiences (replay buffer).

# %%
import gymnasium as gym
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import random
from collections import deque

# %% [markdown]
# # Random Seed
#
# Setting a random seed ensures reproducibility, making experiments consistent across runs.

# %%
seed = 42
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)

# %% [markdown]
# # Replay Buffer
#
# A data structure to store experiences from the environment for training.
#
# push: Adds experiences to the buffer.
#
# sample: Returns a random sample of experiences for training.
#
# __len__: Returns the current size of the buffer.

# %%
class ReplayBuffer:
    def __init__(self, capacity):
        self.buffer = deque(maxlen=capacity)
    
    def push(self, state, action, reward, next_state, done):
        self.buffer.append((state, action, reward, next_state, done))
    
    def sample(self, batch_size):
        state, action, reward, next_state, done = zip(*random.sample(self.buffer, batch_size))
        return np.array(state), np.array(action), np.array(reward), np.array(next_state), np.array(done)
    
    def __len__(self):
        return len(self.buffer)

# %% [markdown]
# # Neural Network
#
# A simple neural network with two hidden layers (36 and 48 neurons).
#
# ReLU activation functions add non-linearity.
#
# input_dim and output_dim correspond to the state and action spaces of the environment, respectively.

# %%
def create_network(input_dim, output_dim):
    return nn.Sequential(
        nn.Linear(input_dim, 36), # input to 1st hidden layer
        nn.ReLU(),                # activation Function
        nn.Linear(36, 48),        # 1st hidden layer to 2nd hidden layer
        nn.ReLU(),                # activation Function
        nn.Linear(48, output_dim) # 2nd hidden layer to output layer
    )

# %% [markdown]
# # DQN Agent
#
# Initializes the agent with key parameters for training and exploration.
#
# env: The environment.
# \
# buffer_capacity: Maximum size of the replay buffer.
# \
# batch_size: Number of experiences sampled for training.
# \
# gamma: Discount factor for future rewards.
# \
# epsilon_start, epsilon_end, epsilon_decay: Parameters for the epsilon-greedy policy, controlling exploration.
# \
# target_update: Frequency of target network updates.
# \
# lr: Learning rate for the optimizer.
#
#
#
# Network and Optimizer
#
# train_network: The primary network for learning.
# \
# target_network: Used to compute target Q-values.
# \
# to(self.device): Moves the network to GPU or CPU.
# \
# optimizer: Optimizes the network weights using the Adam optimizer.
# \
# target_network.load_state_dict: Copies weights from the training network.
# \
# target_network.eval(): Puts the target network in evaluation mode.

# %%
class DQNAgent:
    def __init__(self, env, buffer_capacity=10000, batch_size=50, gamma=0.99, epsilon_start=1.0, epsilon_end=0.01, epsilon_decay=0.995, target_update=10, lr=0.001):
        self.env = env
        self.batch_size = batch_size
        self.gamma = gamma
        self.epsilon = epsilon_start
        self.epsilon_min = epsilon_end
        self.epsilon_decay = epsilon_decay
        self.target_update = target_update
        self.replay_buffer = ReplayBuffer(buffer_capacity)
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        
        # Print the device information
        if self.device.type == 'cuda':
            print("Using GPU for training")
        else:
            print("Using CPU for training")
        
        self.train_network = create_network(env.observation_space.shape[0], env.action_space.n).to(self.device)
        self.target_network = create_network(env.observation_space.shape[0], env.action_space.n).to(self.device)
        self.optimizer = optim.Adam(self.train_network.parameters(), lr=lr)
        
        self.target_network.load_state_dict(self.train_network.state_dict())
        self.target_network.eval()
        
# Chooses an action using an epsilon-greedy strategy, balancing exploration and exploitation.   
     
    def select_action(self, state, epsilon=0.0):
        if random.random() < epsilon:
            return self.env.action_space.sample()
        state = torch.FloatTensor(state).unsqueeze(0).to(self.device)
        with torch.no_grad():
            q_values = self.train_network(state)
        return q_values.cpu().numpy().argmax()
    
# Samples experiences from the replay buffer.Computes the target Q-values
# Updates the training network using gradient descent.
     
    def update(self):
        if len(self.replay_buffer) < self.batch_size:
            return
        
        states, actions, rewards, next_states, dones = self.replay_buffer.sample(self.batch_size)
        
        states = torch.FloatTensor(states).to(self.device)
        actions = torch.LongTensor(actions).to(self.device)
        rewards = torch.FloatTensor(rewards).to(self.device)
        next_states = torch.FloatTensor(next_states).to(self.device)
        dones = torch.FloatTensor(dones).to(self.device)
        
        q_values = self.train_network(states).gather(1, actions.unsqueeze(1)).squeeze(1)
        next_q_values = self.target_network(next_states).max(1)[0]
        target_q_values = rewards + (self.gamma * next_q_values * (1 - dones))
        
        loss = nn.MSELoss()(q_values, target_q_values.detach())
        
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

# Iterates through episodes, interacting with the environment, storing experiences, and training the network.
# Updates the target network periodically.
# Reduces epsilon over time to decrease exploration.

    def train(self, num_episodes, save_path="dqn_model1.pth"):
        for episode in range(num_episodes):
            state, _ = self.env.reset(seed=episode)
            cumulative_reward = 0
            for step in range(200):
                self.env.render()
                action = self.select_action(state, self.epsilon)
                next_state, reward, terminated, truncated, _ = self.env.step(action)
                self.replay_buffer.push(state, action, reward, next_state, terminated or truncated)
                state = next_state
                cumulative_reward += reward
                self.update()

                if terminated:
                    break

            print(f"Episode {episode} finished after {step + 1} steps with cumulative reward {cumulative_reward}")
            if self.epsilon > self.epsilon_min:
                self.epsilon *= self.epsilon_decay
            
            if episode % self.target_update == 0:
                self.target_network.load_state_dict(self.train_network.state_dict())

        # Save the model at the end of training
        torch.save(self.train_network.state_dict(), save_path)
        print(f"Model saved to {save_path}")

# %% [markdown]
# # Main
#
# gym.make('MountainCar-v0', render_mode='human'): Initializes the environment with rendering enabled.
#
# DQNAgent: Initializes the agent with the specified environment and parameters.
#
# agent.train(num_episodes=1000): Trains the agent for 1000 episodes.

# %%
env = gym.make('MountainCar-v0', render_mode=None)
agent = DQNAgent(env)
agent.train(num_episodes=2500)
# Out:
# Using GPU for training
# c:\Users\abhay\anaconda3\envs\rl\Lib\site-packages\gymnasium\envs\classic_control\mountain_car.py:173: UserWarning: WARN: You are calling render method without specifying any render mode. You can specify the render_mode at initialization, e.g. gym.make("MountainCar-v0", render_mode="rgb_array")
#   gym.logger.warn(
# Episode 0 finished after 200 steps with cumulative reward -200.0
# Episode 1 finished after 200 steps with cumulative reward -200.0
# Episode 2 finished after 200 steps with cumulative reward -200.0
# Episode 3 finished after 200 steps with cumulative reward -200.0
# Episode 4 finished after 200 steps with cumulative reward -200.0
# Episode 5 finished after 200 steps with cumulative reward -200.0
# Episode 6 finished after 200 steps with cumulative reward -200.0
# Episode 7 finished after 200 steps with cumulative reward -200.0
# Episode 8 finished after 200 steps with cumulative reward -200.0
# Episode 9 finished after 200 steps with cumulative reward -200.0
# Episode 10 finished after 200 steps with cumulative reward -200.0
# Episode 11 finished after 200 steps with cumulative reward -200.0
# Episode 12 finished after 200 steps with cumulative reward -200.0
# Episode 13 finished after 200 steps with cumulative reward -200.0
# Episode 14 finished after 200 steps with cumulative reward -200.0
# Episode 15 finished after 200 steps with cumulative reward -200.0
# Episode 16 finished after 200 steps with cumulative reward -200.0
# Episode 17 finished after 200 steps with cumulative reward -200.0
# Episode 18 finished after 200 steps with cumulative reward -200.0
# Episode 19 finished after 200 steps with cumulative reward -200.0
# Episode 20 finished after 200 steps with cumulative reward -200.0
# Episode 21 finished after 200 steps with cumulative reward -200.0
# Episode 22 finished after 200 steps with cumulative reward -200.0
# Episode 23 finished after 200 steps with cumulative reward -200.0
# Episode 24 finished after 200 steps with cumulative reward -200.0
# Episode 25 finished after 200 steps with cumulative reward -200.0
# Episode 26 finished after 200 steps with cumulative reward -200.0
# Episode 27 finished after 200 steps with cumulative reward -200.0
# Episode 28 finished after 200 steps with cumulative reward -200.0
# Episode 29 finished after 200 steps with cumulative reward -200.0
# Episode 30 finished after 200 steps with cumulative reward -200.0
# Episode 31 finished after 200 steps with cumulative reward -200.0
# Episode 32 finished after 200 steps with cumulative reward -200.0
# Episode 33 finished after 200 steps with cumulative reward -200.0
# Episode 34 finished after 200 steps with cumulative reward -200.0
# Episode 35 finished after 200 steps with cumulative reward -200.0
# Episode 36 finished after 200 steps with cumulative reward -200.0
# Episode 37 finished after 200 steps with cumulative reward -200.0
# Episode 38 finished after 200 steps with cumulative reward -200.0
# Episode 39 finished after 200 steps with cumulative reward -200.0
# Episode 40 finished after 200 steps with cumulative reward -200.0
# Episode 41 finished after 200 steps with cumulative reward -200.0
# Episode 42 finished after 200 steps with cumulative reward -200.0
# Episode 43 finished after 200 steps with cumulative reward -200.0
# Episode 44 finished after 200 steps with cumulative reward -200.0
# Episode 45 finished after 200 steps with cumulative reward -200.0
# Episode 46 finished after 200 steps with cumulative reward -200.0
# Episode 47 finished after 200 steps with cumulative reward -200.0
# Episode 48 finished after 200 steps with cumulative reward -200.0
# Episode 49 finished after 200 steps with cumulative reward -200.0
# Episode 50 finished after 200 steps with cumulative reward -200.0
# Episode 51 finished after 200 steps with cumulative reward -200.0
# Episode 52 finished after 200 steps with cumulative reward -200.0
# Episode 53 finished after 200 steps with cumulative reward -200.0
# Episode 54 finished after 200 steps with cumulative reward -200.0
# Episode 55 finished after 200 steps with cumulative reward -200.0
# Episode 56 finished after 200 steps with cumulative reward -200.0
# Episode 57 finished after 200 steps with cumulative reward -200.0
# Episode 58 finished after 200 steps with cumulative reward -200.0
# Episode 59 finished after 200 steps with cumulative reward -200.0
# Episode 60 finished after 200 steps with cumulative reward -200.0
# Episode 61 finished after 200 steps with cumulative reward -200.0
# Episode 62 finished after 200 steps with cumulative reward -200.0
# Episode 63 finished after 200 steps with cumulative reward -200.0
# Episode 64 finished after 200 steps with cumulative reward -200.0
# Episode 65 finished after 200 steps with cumulative reward -200.0
# Episode 66 finished after 200 steps with cumulative reward -200.0
# Episode 67 finished after 200 steps with cumulative reward -200.0
# Episode 68 finished after 200 steps with cumulative reward -200.0
# Episode 69 finished after 200 steps with cumulative reward -200.0
# Episode 70 finished after 200 steps with cumulative reward -200.0
# Episode 71 finished after 200 steps with cumulative reward -200.0
# Episode 72 finished after 200 steps with cumulative reward -200.0
# Episode 73 finished after 200 steps with cumulative reward -200.0
# Episode 74 finished after 200 steps with cumulative reward -200.0
# Episode 75 finished after 200 steps with cumulative reward -200.0
# Episode 76 finished after 200 steps with cumulative reward -200.0
# Episode 77 finished after 200 steps with cumulative reward -200.0
# Episode 78 finished after 200 steps with cumulative reward -200.0
# Episode 79 finished after 200 steps with cumulative reward -200.0
# Episode 80 finished after 200 steps with cumulative reward -200.0
# Episode 81 finished after 200 steps with cumulative reward -200.0
# Episode 82 finished after 200 steps with cumulative reward -200.0
# Episode 83 finished after 200 steps with cumulative reward -200.0
# Episode 84 finished after 200 steps with cumulative reward -200.0
# Episode 85 finished after 200 steps with cumulative reward -200.0
# Episode 86 finished after 200 steps with cumulative reward -200.0
# Episode 87 finished after 200 steps with cumulative reward -200.0
# Episode 88 finished after 200 steps with cumulative reward -200.0
# Episode 89 finished after 200 steps with cumulative reward -200.0
# Episode 90 finished after 200 steps with cumulative reward -200.0
# Episode 91 finished after 200 steps with cumulative reward -200.0
# Episode 92 finished after 200 steps with cumulative reward -200.0
# Episode 93 finished after 200 steps with cumulative reward -200.0
# Episode 94 finished after 200 steps with cumulative reward -200.0
# Episode 95 finished after 200 steps with cumulative reward -200.0
# Episode 96 finished after 200 steps with cumulative reward -200.0
# Episode 97 finished after 200 steps with cumulative reward -200.0
# Episode 98 finished after 200 steps with cumulative reward -200.0
# Episode 99 finished after 200 steps with cumulative reward -200.0
# Episode 100 finished after 200 steps with cumulative reward -200.0
# Episode 101 finished after 200 steps with cumulative reward -200.0
# Episode 102 finished after 200 steps with cumulative reward -200.0
# Episode 103 finished after 200 steps with cumulative reward -200.0
# Episode 104 finished after 200 steps with cumulative reward -200.0
# Episode 105 finished after 200 steps with cumulative reward -200.0
# Episode 106 finished after 200 steps with cumulative reward -200.0
# Episode 107 finished after 200 steps with cumulative reward -200.0
# Episode 108 finished after 200 steps with cumulative reward -200.0
# Episode 109 finished after 200 steps with cumulative reward -200.0
# Episode 110 finished after 200 steps with cumulative reward -200.0
# Episode 111 finished after 200 steps with cumulative reward -200.0
# Episode 112 finished after 200 steps with cumulative reward -200.0
# Episode 113 finished after 200 steps with cumulative reward -200.0
# Episode 114 finished after 200 steps with cumulative reward -200.0
# Episode 115 finished after 200 steps with cumulative reward -200.0
# Episode 116 finished after 200 steps with cumulative reward -200.0
# Episode 117 finished after 200 steps with cumulative reward -200.0
# Episode 118 finished after 200 steps with cumulative reward -200.0
# Episode 119 finished after 200 steps with cumulative reward -200.0
# Episode 120 finished after 200 steps with cumulative reward -200.0
# Episode 121 finished after 200 steps with cumulative reward -200.0
# Episode 122 finished after 200 steps with cumulative reward -200.0
# Episode 123 finished after 200 steps with cumulative reward -200.0
# Episode 124 finished after 200 steps with cumulative reward -200.0
# Episode 125 finished after 200 steps with cumulative reward -200.0
# Episode 126 finished after 200 steps with cumulative reward -200.0
# Episode 127 finished after 200 steps with cumulative reward -200.0
# Episode 128 finished after 200 steps with cumulative reward -200.0
# Episode 129 finished after 200 steps with cumulative reward -200.0
# Episode 130 finished after 200 steps with cumulative reward -200.0
# Episode 131 finished after 200 steps with cumulative reward -200.0
# Episode 132 finished after 200 steps with cumulative reward -200.0
# Episode 133 finished after 200 steps with cumulative reward -200.0
# Episode 134 finished after 200 steps with cumulative reward -200.0
# Episode 135 finished after 200 steps with cumulative reward -200.0
# Episode 136 finished after 200 steps with cumulative reward -200.0
# Episode 137 finished after 200 steps with cumulative reward -200.0
# Episode 138 finished after 200 steps with cumulative reward -200.0
# Episode 139 finished after 200 steps with cumulative reward -200.0
# Episode 140 finished after 200 steps with cumulative reward -200.0
# Episode 141 finished after 200 steps with cumulative reward -200.0
# Episode 142 finished after 200 steps with cumulative reward -200.0
# Episode 143 finished after 200 steps with cumulative reward -200.0
# Episode 144 finished after 200 steps with cumulative reward -200.0
# Episode 145 finished after 200 steps with cumulative reward -200.0
# Episode 146 finished after 200 steps with cumulative reward -200.0
# Episode 147 finished after 200 steps with cumulative reward -200.0
# Episode 148 finished after 200 steps with cumulative reward -200.0
# Episode 149 finished after 200 steps with cumulative reward -200.0
# Episode 150 finished after 200 steps with cumulative reward -200.0
# Episode 151 finished after 200 steps with cumulative reward -200.0
# Episode 152 finished after 200 steps with cumulative reward -200.0
# Episode 153 finished after 200 steps with cumulative reward -200.0
# Episode 154 finished after 200 steps with cumulative reward -200.0
# Episode 155 finished after 200 steps with cumulative reward -200.0
# Episode 156 finished after 200 steps with cumulative reward -200.0
# Episode 157 finished after 200 steps with cumulative reward -200.0
# Episode 158 finished after 200 steps with cumulative reward -200.0
# Episode 159 finished after 200 steps with cumulative reward -200.0
# Episode 160 finished after 200 steps with cumulative reward -200.0
# Episode 161 finished after 200 steps with cumulative reward -200.0
# Episode 162 finished after 200 steps with cumulative reward -200.0
# Episode 163 finished after 200 steps with cumulative reward -200.0
# Episode 164 finished after 200 steps with cumulative reward -200.0
# Episode 165 finished after 200 steps with cumulative reward -200.0
# Episode 166 finished after 200 steps with cumulative reward -200.0
# Episode 167 finished after 200 steps with cumulative reward -200.0
# Episode 168 finished after 200 steps with cumulative reward -200.0
# Episode 169 finished after 200 steps with cumulative reward -200.0
# Episode 170 finished after 200 steps with cumulative reward -200.0
# Episode 171 finished after 200 steps with cumulative reward -200.0
# Episode 172 finished after 200 steps with cumulative reward -200.0
# Episode 173 finished after 200 steps with cumulative reward -200.0
# Episode 174 finished after 200 steps with cumulative reward -200.0
# Episode 175 finished after 200 steps with cumulative reward -200.0
# Episode 176 finished after 200 steps with cumulative reward -200.0
# Episode 177 finished after 200 steps with cumulative reward -200.0
# Episode 178 finished after 200 steps with cumulative reward -200.0
# Episode 179 finished after 200 steps with cumulative reward -200.0
# Episode 180 finished after 200 steps with cumulative reward -200.0
# Episode 181 finished after 200 steps with cumulative reward -200.0
# Episode 182 finished after 200 steps with cumulative reward -200.0
# Episode 183 finished after 200 steps with cumulative reward -200.0
# Episode 184 finished after 200 steps with cumulative reward -200.0
# Episode 185 finished after 200 steps with cumulative reward -200.0
# Episode 186 finished after 200 steps with cumulative reward -200.0
# Episode 187 finished after 200 steps with cumulative reward -200.0
# Episode 188 finished after 200 steps with cumulative reward -200.0
# Episode 189 finished after 200 steps with cumulative reward -200.0
# Episode 190 finished after 200 steps with cumulative reward -200.0
# Episode 191 finished after 200 steps with cumulative reward -200.0
# Episode 192 finished after 200 steps with cumulative reward -200.0
# Episode 193 finished after 200 steps with cumulative reward -200.0
# Episode 194 finished after 200 steps with cumulative reward -200.0
# Episode 195 finished after 200 steps with cumulative reward -200.0
# Episode 196 finished after 200 steps with cumulative reward -200.0
# Episode 197 finished after 200 steps with cumulative reward -200.0
# Episode 198 finished after 200 steps with cumulative reward -200.0
# Episode 199 finished after 200 steps with cumulative reward -200.0
# Episode 200 finished after 200 steps with cumulative reward -200.0
# Episode 201 finished after 200 steps with cumulative reward -200.0
# Episode 202 finished after 200 steps with cumulative reward -200.0
# Episode 203 finished after 200 steps with cumulative reward -200.0
# Episode 204 finished after 200 steps with cumulative reward -200.0
# Episode 205 finished after 200 steps with cumulative reward -200.0
# Episode 206 finished after 200 steps with cumulative reward -200.0
# Episode 207 finished after 200 steps with cumulative reward -200.0
# Episode 208 finished after 200 steps with cumulative reward -200.0
# Episode 209 finished after 200 steps with cumulative reward -200.0
# Episode 210 finished after 200 steps with cumulative reward -200.0
# Episode 211 finished after 200 steps with cumulative reward -200.0
# Episode 212 finished after 200 steps with cumulative reward -200.0
# Episode 213 finished after 200 steps with cumulative reward -200.0
# Episode 214 finished after 200 steps with cumulative reward -200.0
# Episode 215 finished after 200 steps with cumulative reward -200.0
# Episode 216 finished after 200 steps with cumulative reward -200.0
# Episode 217 finished after 200 steps with cumulative reward -200.0
# Episode 218 finished after 200 steps with cumulative reward -200.0
# Episode 219 finished after 200 steps with cumulative reward -200.0
# Episode 220 finished after 200 steps with cumulative reward -200.0
# Episode 221 finished after 200 steps with cumulative reward -200.0
# Episode 222 finished after 200 steps with cumulative reward -200.0
# Episode 223 finished after 200 steps with cumulative reward -200.0
# Episode 224 finished after 200 steps with cumulative reward -200.0
# Episode 225 finished after 200 steps with cumulative reward -200.0
# Episode 226 finished after 200 steps with cumulative reward -200.0
# Episode 227 finished after 200 steps with cumulative reward -200.0
# Episode 228 finished after 200 steps with cumulative reward -200.0
# Episode 229 finished after 200 steps with cumulative reward -200.0
# Episode 230 finished after 200 steps with cumulative reward -200.0
# Episode 231 finished after 200 steps with cumulative reward -200.0
# Episode 232 finished after 200 steps with cumulative reward -200.0
# Episode 233 finished after 200 steps with cumulative reward -200.0
# Episode 234 finished after 200 steps with cumulative reward -200.0
# Episode 235 finished after 200 steps with cumulative reward -200.0
# Episode 236 finished after 200 steps with cumulative reward -200.0
# Episode 237 finished after 200 steps with cumulative reward -200.0
# Episode 238 finished after 200 steps with cumulative reward -200.0
# Episode 239 finished after 200 steps with cumulative reward -200.0
# Episode 240 finished after 200 steps with cumulative reward -200.0
# Episode 241 finished after 200 steps with cumulative reward -200.0
# Episode 242 finished after 200 steps with cumulative reward -200.0
# Episode 243 finished after 200 steps with cumulative reward -200.0
# Episode 244 finished after 200 steps with cumulative reward -200.0
# Episode 245 finished after 200 steps with cumulative reward -200.0
# Episode 246 finished after 200 steps with cumulative reward -200.0
# Episode 247 finished after 200 steps with cumulative reward -200.0
# Episode 248 finished after 200 steps with cumulative reward -200.0
# Episode 249 finished after 200 steps with cumulative reward -200.0
# Episode 250 finished after 200 steps with cumulative reward -200.0
# Episode 251 finished after 200 steps with cumulative reward -200.0
# Episode 252 finished after 200 steps with cumulative reward -200.0
# Episode 253 finished after 200 steps with cumulative reward -200.0
# Episode 254 finished after 200 steps with cumulative reward -200.0
# Episode 255 finished after 200 steps with cumulative reward -200.0
# Episode 256 finished after 200 steps with cumulative reward -200.0
# Episode 257 finished after 200 steps with cumulative reward -200.0
# Episode 258 finished after 200 steps with cumulative reward -200.0
# Episode 259 finished after 200 steps with cumulative reward -200.0
# Episode 260 finished after 200 steps with cumulative reward -200.0
# Episode 261 finished after 200 steps with cumulative reward -200.0
# Episode 262 finished after 200 steps with cumulative reward -200.0
# Episode 263 finished after 200 steps with cumulative reward -200.0
# Episode 264 finished after 200 steps with cumulative reward -200.0
# Episode 265 finished after 200 steps with cumulative reward -200.0
# Episode 266 finished after 200 steps with cumulative reward -200.0
# Episode 267 finished after 200 steps with cumulative reward -200.0
# Episode 268 finished after 200 steps with cumulative reward -200.0
# Episode 269 finished after 200 steps with cumulative reward -200.0
# Episode 270 finished after 200 steps with cumulative reward -200.0
# Episode 271 finished after 200 steps with cumulative reward -200.0
# Episode 272 finished after 200 steps with cumulative reward -200.0
# Episode 273 finished after 200 steps with cumulative reward -200.0
# Episode 274 finished after 200 steps with cumulative reward -200.0
# Episode 275 finished after 200 steps with cumulative reward -200.0
# Episode 276 finished after 200 steps with cumulative reward -200.0
# Episode 277 finished after 200 steps with cumulative reward -200.0
# Episode 278 finished after 200 steps with cumulative reward -200.0
# Episode 279 finished after 200 steps with cumulative reward -200.0
# Episode 280 finished after 200 steps with cumulative reward -200.0
# Episode 281 finished after 200 steps with cumulative reward -200.0
# Episode 282 finished after 200 steps with cumulative reward -200.0
# Episode 283 finished after 200 steps with cumulative reward -200.0
# Episode 284 finished after 200 steps with cumulative reward -200.0
# Episode 285 finished after 200 steps with cumulative reward -200.0
# Episode 286 finished after 200 steps with cumulative reward -200.0
# Episode 287 finished after 200 steps with cumulative reward -200.0
# Episode 288 finished after 200 steps with cumulative reward -200.0
# Episode 289 finished after 200 steps with cumulative reward -200.0
# Episode 290 finished after 200 steps with cumulative reward -200.0
# Episode 291 finished after 200 steps with cumulative reward -200.0
# Episode 292 finished after 200 steps with cumulative reward -200.0
# Episode 293 finished after 200 steps with cumulative reward -200.0
# Episode 294 finished after 200 steps with cumulative reward -200.0
# Episode 295 finished after 200 steps with cumulative reward -200.0
# Episode 296 finished after 200 steps with cumulative reward -200.0
# Episode 297 finished after 200 steps with cumulative reward -200.0
# Episode 298 finished after 200 steps with cumulative reward -200.0
# Episode 299 finished after 200 steps with cumulative reward -200.0
# Episode 300 finished after 200 steps with cumulative reward -200.0
# Episode 301 finished after 200 steps with cumulative reward -200.0
# Episode 302 finished after 200 steps with cumulative reward -200.0
# Episode 303 finished after 200 steps with cumulative reward -200.0
# Episode 304 finished after 200 steps with cumulative reward -200.0
# Episode 305 finished after 200 steps with cumulative reward -200.0
# Episode 306 finished after 200 steps with cumulative reward -200.0
# Episode 307 finished after 195 steps with cumulative reward -195.0
# Episode 308 finished after 200 steps with cumulative reward -200.0
# Episode 309 finished after 200 steps with cumulative reward -200.0
# Episode 310 finished after 200 steps with cumulative reward -200.0
# Episode 311 finished after 200 steps with cumulative reward -200.0
# Episode 312 finished after 200 steps with cumulative reward -200.0
# Episode 313 finished after 200 steps with cumulative reward -200.0
# Episode 314 finished after 200 steps with cumulative reward -200.0
# Episode 315 finished after 200 steps with cumulative reward -200.0
# Episode 316 finished after 200 steps with cumulative reward -200.0
# Episode 317 finished after 200 steps with cumulative reward -200.0
# Episode 318 finished after 200 steps with cumulative reward -200.0
# Episode 319 finished after 200 steps with cumulative reward -200.0
# Episode 320 finished after 200 steps with cumulative reward -200.0
# Episode 321 finished after 164 steps with cumulative reward -164.0
# Episode 322 finished after 200 steps with cumulative reward -200.0
# Episode 323 finished after 200 steps with cumulative reward -200.0
# Episode 324 finished after 200 steps with cumulative reward -200.0
# Episode 325 finished after 200 steps with cumulative reward -200.0
# Episode 326 finished after 200 steps with cumulative reward -200.0
# Episode 327 finished after 200 steps with cumulative reward -200.0
# Episode 328 finished after 200 steps with cumulative reward -200.0
# Episode 329 finished after 200 steps with cumulative reward -200.0
# Episode 330 finished after 200 steps with cumulative reward -200.0
# Episode 331 finished after 200 steps with cumulative reward -200.0
# Episode 332 finished after 200 steps with cumulative reward -200.0
# Episode 333 finished after 200 steps with cumulative reward -200.0
# Episode 334 finished after 200 steps with cumulative reward -200.0
# Episode 335 finished after 200 steps with cumulative reward -200.0
# Episode 336 finished after 200 steps with cumulative reward -200.0
# Episode 337 finished after 200 steps with cumulative reward -200.0
# Episode 338 finished after 200 steps with cumulative reward -200.0
# Episode 339 finished after 200 steps with cumulative reward -200.0
# Episode 340 finished after 200 steps with cumulative reward -200.0
# Episode 341 finished after 200 steps with cumulative reward -200.0
# Episode 342 finished after 200 steps with cumulative reward -200.0
# Episode 343 finished after 200 steps with cumulative reward -200.0
# Episode 344 finished after 200 steps with cumulative reward -200.0
# Episode 345 finished after 200 steps with cumulative reward -200.0
# Episode 346 finished after 200 steps with cumulative reward -200.0
# Episode 347 finished after 200 steps with cumulative reward -200.0
# Episode 348 finished after 200 steps with cumulative reward -200.0
# Episode 349 finished after 200 steps with cumulative reward -200.0
# Episode 350 finished after 200 steps with cumulative reward -200.0
# Episode 351 finished after 200 steps with cumulative reward -200.0
# Episode 352 finished after 200 steps with cumulative reward -200.0
# Episode 353 finished after 200 steps with cumulative reward -200.0
# Episode 354 finished after 200 steps with cumulative reward -200.0
# Episode 355 finished after 200 steps with cumulative reward -200.0
# Episode 356 finished after 200 steps with cumulative reward -200.0
# Episode 357 finished after 200 steps with cumulative reward -200.0
# Episode 358 finished after 200 steps with cumulative reward -200.0
# Episode 359 finished after 200 steps with cumulative reward -200.0
# Episode 360 finished after 173 steps with cumulative reward -173.0
# Episode 361 finished after 200 steps with cumulative reward -200.0
# Episode 362 finished after 200 steps with cumulative reward -200.0
# Episode 363 finished after 200 steps with cumulative reward -200.0
# Episode 364 finished after 200 steps with cumulative reward -200.0
# Episode 365 finished after 200 steps with cumulative reward -200.0
# Episode 366 finished after 200 steps with cumulative reward -200.0
# Episode 367 finished after 200 steps with cumulative reward -200.0
# Episode 368 finished after 200 steps with cumulative reward -200.0
# Episode 369 finished after 200 steps with cumulative reward -200.0
# Episode 370 finished after 200 steps with cumulative reward -200.0
# Episode 371 finished after 200 steps with cumulative reward -200.0
# Episode 372 finished after 200 steps with cumulative reward -200.0
# Episode 373 finished after 200 steps with cumulative reward -200.0
# Episode 374 finished after 200 steps with cumulative reward -200.0
# Episode 375 finished after 200 steps with cumulative reward -200.0
# Episode 376 finished after 200 steps with cumulative reward -200.0
# Episode 377 finished after 200 steps with cumulative reward -200.0
# Episode 378 finished after 200 steps with cumulative reward -200.0
# Episode 379 finished after 200 steps with cumulative reward -200.0
# Episode 380 finished after 200 steps with cumulative reward -200.0
# Episode 381 finished after 200 steps with cumulative reward -200.0
# Episode 382 finished after 200 steps with cumulative reward -200.0
# Episode 383 finished after 200 steps with cumulative reward -200.0
# Episode 384 finished after 200 steps with cumulative reward -200.0
# Episode 385 finished after 200 steps with cumulative reward -200.0
# Episode 386 finished after 200 steps with cumulative reward -200.0
# Episode 387 finished after 200 steps with cumulative reward -200.0
# Episode 388 finished after 200 steps with cumulative reward -200.0
# Episode 389 finished after 200 steps with cumulative reward -200.0
# Episode 390 finished after 200 steps with cumulative reward -200.0
# Episode 391 finished after 200 steps with cumulative reward -200.0
# Episode 392 finished after 200 steps with cumulative reward -200.0
# Episode 393 finished after 200 steps with cumulative reward -200.0
# Episode 394 finished after 200 steps with cumulative reward -200.0
# Episode 395 finished after 200 steps with cumulative reward -200.0
# Episode 396 finished after 200 steps with cumulative reward -200.0
# Episode 397 finished after 200 steps with cumulative reward -200.0
# Episode 398 finished after 200 steps with cumulative reward -200.0
# Episode 399 finished after 200 steps with cumulative reward -200.0
# Episode 400 finished after 200 steps with cumulative reward -200.0
# Episode 401 finished after 200 steps with cumulative reward -200.0
# Episode 402 finished after 200 steps with cumulative reward -200.0
# Episode 403 finished after 200 steps with cumulative reward -200.0
# Episode 404 finished after 200 steps with cumulative reward -200.0
# Episode 405 finished after 200 steps with cumulative reward -200.0
# Episode 406 finished after 200 steps with cumulative reward -200.0
# Episode 407 finished after 200 steps with cumulative reward -200.0
# Episode 408 finished after 200 steps with cumulative reward -200.0
# Episode 409 finished after 200 steps with cumulative reward -200.0
# Episode 410 finished after 200 steps with cumulative reward -200.0
# Episode 411 finished after 200 steps with cumulative reward -200.0
# Episode 412 finished after 200 steps with cumulative reward -200.0
# Episode 413 finished after 200 steps with cumulative reward -200.0
# Episode 414 finished after 151 steps with cumulative reward -151.0
# Episode 415 finished after 200 steps with cumulative reward -200.0
# Episode 416 finished after 200 steps with cumulative reward -200.0
# Episode 417 finished after 172 steps with cumulative reward -172.0
# Episode 418 finished after 200 steps with cumulative reward -200.0
# Episode 419 finished after 200 steps with cumulative reward -200.0
# Episode 420 finished after 200 steps with cumulative reward -200.0
# Episode 421 finished after 200 steps with cumulative reward -200.0
# Episode 422 finished after 191 steps with cumulative reward -191.0
# Episode 423 finished after 200 steps with cumulative reward -200.0
# Episode 424 finished after 200 steps with cumulative reward -200.0
# Episode 425 finished after 200 steps with cumulative reward -200.0
# Episode 426 finished after 200 steps with cumulative reward -200.0
# Episode 427 finished after 200 steps with cumulative reward -200.0
# Episode 428 finished after 200 steps with cumulative reward -200.0
# Episode 429 finished after 200 steps with cumulative reward -200.0
# Episode 430 finished after 200 steps with cumulative reward -200.0
# Episode 431 finished after 200 steps with cumulative reward -200.0
# Episode 432 finished after 200 steps with cumulative reward -200.0
# Episode 433 finished after 200 steps with cumulative reward -200.0
# Episode 434 finished after 200 steps with cumulative reward -200.0
# Episode 435 finished after 200 steps with cumulative reward -200.0
# Episode 436 finished after 200 steps with cumulative reward -200.0
# Episode 437 finished after 200 steps with cumulative reward -200.0
# Episode 438 finished after 94 steps with cumulative reward -94.0
# Episode 439 finished after 200 steps with cumulative reward -200.0
# Episode 440 finished after 200 steps with cumulative reward -200.0
# Episode 441 finished after 200 steps with cumulative reward -200.0
# Episode 442 finished after 200 steps with cumulative reward -200.0
# Episode 443 finished after 200 steps with cumulative reward -200.0
# Episode 444 finished after 200 steps with cumulative reward -200.0
# Episode 445 finished after 200 steps with cumulative reward -200.0
# Episode 446 finished after 200 steps with cumulative reward -200.0
# Episode 447 finished after 200 steps with cumulative reward -200.0
# Episode 448 finished after 165 steps with cumulative reward -165.0
# Episode 449 finished after 200 steps with cumulative reward -200.0
# Episode 450 finished after 200 steps with cumulative reward -200.0
# Episode 451 finished after 200 steps with cumulative reward -200.0
# Episode 452 finished after 200 steps with cumulative reward -200.0
# Episode 453 finished after 200 steps with cumulative reward -200.0
# Episode 454 finished after 200 steps with cumulative reward -200.0
# Episode 455 finished after 124 steps with cumulative reward -124.0
# Episode 456 finished after 200 steps with cumulative reward -200.0
# Episode 457 finished after 200 steps with cumulative reward -200.0
# Episode 458 finished after 200 steps with cumulative reward -200.0
# Episode 459 finished after 200 steps with cumulative reward -200.0
# Episode 460 finished after 200 steps with cumulative reward -200.0
# Episode 461 finished after 200 steps with cumulative reward -200.0
# Episode 462 finished after 193 steps with cumulative reward -193.0
# Episode 463 finished after 200 steps with cumulative reward -200.0
# Episode 464 finished after 200 steps with cumulative reward -200.0
# Episode 465 finished after 200 steps with cumulative reward -200.0
# Episode 466 finished after 200 steps with cumulative reward -200.0
# Episode 467 finished after 200 steps with cumulative reward -200.0
# Episode 468 finished after 200 steps with cumulative reward -200.0
# Episode 469 finished after 200 steps with cumulative reward -200.0
# Episode 470 finished after 200 steps with cumulative reward -200.0
# Episode 471 finished after 200 steps with cumulative reward -200.0
# Episode 472 finished after 200 steps with cumulative reward -200.0
# Episode 473 finished after 200 steps with cumulative reward -200.0
# Episode 474 finished after 200 steps with cumulative reward -200.0
# Episode 475 finished after 200 steps with cumulative reward -200.0
# Episode 476 finished after 200 steps with cumulative reward -200.0
# Episode 477 finished after 200 steps with cumulative reward -200.0
# Episode 478 finished after 200 steps with cumulative reward -200.0
# Episode 479 finished after 200 steps with cumulative reward -200.0
# Episode 480 finished after 200 steps with cumulative reward -200.0
# Episode 481 finished after 200 steps with cumulative reward -200.0
# Episode 482 finished after 200 steps with cumulative reward -200.0
# Episode 483 finished after 145 steps with cumulative reward -145.0
# Episode 484 finished after 200 steps with cumulative reward -200.0
# Episode 485 finished after 109 steps with cumulative reward -109.0
# Episode 486 finished after 180 steps with cumulative reward -180.0
# Episode 487 finished after 138 steps with cumulative reward -138.0
# Episode 488 finished after 200 steps with cumulative reward -200.0
# Episode 489 finished after 200 steps with cumulative reward -200.0
# Episode 490 finished after 200 steps with cumulative reward -200.0
# Episode 491 finished after 200 steps with cumulative reward -200.0
# Episode 492 finished after 173 steps with cumulative reward -173.0
# Episode 493 finished after 174 steps with cumulative reward -174.0
# Episode 494 finished after 180 steps with cumulative reward -180.0
# Episode 495 finished after 200 steps with cumulative reward -200.0
# Episode 496 finished after 165 steps with cumulative reward -165.0
# Episode 497 finished after 200 steps with cumulative reward -200.0
# Episode 498 finished after 175 steps with cumulative reward -175.0
# Episode 499 finished after 190 steps with cumulative reward -190.0
# Episode 500 finished after 200 steps with cumulative reward -200.0
# Episode 501 finished after 200 steps with cumulative reward -200.0
# Episode 502 finished after 200 steps with cumulative reward -200.0
# Episode 503 finished after 170 steps with cumulative reward -170.0
# Episode 504 finished after 200 steps with cumulative reward -200.0
# Episode 505 finished after 200 steps with cumulative reward -200.0
# Episode 506 finished after 200 steps with cumulative reward -200.0
# Episode 507 finished after 200 steps with cumulative reward -200.0
# Episode 508 finished after 200 steps with cumulative reward -200.0
# Episode 509 finished after 200 steps with cumulative reward -200.0
# Episode 510 finished after 149 steps with cumulative reward -149.0
# Episode 511 finished after 200 steps with cumulative reward -200.0
# Episode 512 finished after 200 steps with cumulative reward -200.0
# Episode 513 finished after 200 steps with cumulative reward -200.0
# Episode 514 finished after 200 steps with cumulative reward -200.0
# Episode 515 finished after 200 steps with cumulative reward -200.0
# Episode 516 finished after 200 steps with cumulative reward -200.0
# Episode 517 finished after 200 steps with cumulative reward -200.0
# Episode 518 finished after 151 steps with cumulative reward -151.0
# Episode 519 finished after 162 steps with cumulative reward -162.0
# Episode 520 finished after 125 steps with cumulative reward -125.0
# Episode 521 finished after 200 steps with cumulative reward -200.0
# Episode 522 finished after 200 steps with cumulative reward -200.0
# Episode 523 finished after 200 steps with cumulative reward -200.0
# Episode 524 finished after 200 steps with cumulative reward -200.0
# Episode 525 finished after 200 steps with cumulative reward -200.0
# Episode 526 finished after 179 steps with cumulative reward -179.0
# Episode 527 finished after 148 steps with cumulative reward -148.0
# Episode 528 finished after 200 steps with cumulative reward -200.0
# Episode 529 finished after 119 steps with cumulative reward -119.0
# Episode 530 finished after 200 steps with cumulative reward -200.0
# Episode 531 finished after 200 steps with cumulative reward -200.0
# Episode 532 finished after 165 steps with cumulative reward -165.0
# Episode 533 finished after 200 steps with cumulative reward -200.0
# Episode 534 finished after 200 steps with cumulative reward -200.0
# Episode 535 finished after 200 steps with cumulative reward -200.0
# Episode 536 finished after 183 steps with cumulative reward -183.0
# Episode 537 finished after 191 steps with cumulative reward -191.0
# Episode 538 finished after 158 steps with cumulative reward -158.0
# Episode 539 finished after 200 steps with cumulative reward -200.0
# Episode 540 finished after 177 steps with cumulative reward -177.0
# Episode 541 finished after 200 steps with cumulative reward -200.0
# Episode 542 finished after 115 steps with cumulative reward -115.0
# Episode 543 finished after 200 steps with cumulative reward -200.0
# Episode 544 finished after 132 steps with cumulative reward -132.0
# Episode 545 finished after 173 steps with cumulative reward -173.0
# Episode 546 finished after 158 steps with cumulative reward -158.0
# Episode 547 finished after 200 steps with cumulative reward -200.0
# Episode 548 finished after 200 steps with cumulative reward -200.0
# Episode 549 finished after 183 steps with cumulative reward -183.0
# Episode 550 finished after 156 steps with cumulative reward -156.0
# Episode 551 finished after 200 steps with cumulative reward -200.0
# Episode 552 finished after 200 steps with cumulative reward -200.0
# Episode 553 finished after 177 steps with cumulative reward -177.0
# Episode 554 finished after 147 steps with cumulative reward -147.0
# Episode 555 finished after 200 steps with cumulative reward -200.0
# Episode 556 finished after 177 steps with cumulative reward -177.0
# Episode 557 finished after 147 steps with cumulative reward -147.0
# Episode 558 finished after 164 steps with cumulative reward -164.0
# Episode 559 finished after 170 steps with cumulative reward -170.0
# Episode 560 finished after 200 steps with cumulative reward -200.0
# Episode 561 finished after 179 steps with cumulative reward -179.0
# Episode 562 finished after 200 steps with cumulative reward -200.0
# Episode 563 finished after 200 steps with cumulative reward -200.0
# Episode 564 finished after 200 steps with cumulative reward -200.0
# Episode 565 finished after 200 steps with cumulative reward -200.0
# Episode 566 finished after 158 steps with cumulative reward -158.0
# Episode 567 finished after 147 steps with cumulative reward -147.0
# Episode 568 finished after 200 steps with cumulative reward -200.0
# Episode 569 finished after 200 steps with cumulative reward -200.0
# Episode 570 finished after 173 steps with cumulative reward -173.0
# Episode 571 finished after 200 steps with cumulative reward -200.0
# Episode 572 finished after 179 steps with cumulative reward -179.0
# Episode 573 finished after 200 steps with cumulative reward -200.0
# Episode 574 finished after 138 steps with cumulative reward -138.0
# Episode 575 finished after 135 steps with cumulative reward -135.0
# Episode 576 finished after 200 steps with cumulative reward -200.0
# Episode 577 finished after 200 steps with cumulative reward -200.0
# Episode 578 finished after 185 steps with cumulative reward -185.0
# Episode 579 finished after 200 steps with cumulative reward -200.0
# Episode 580 finished after 109 steps with cumulative reward -109.0
# Episode 581 finished after 172 steps with cumulative reward -172.0
# Episode 582 finished after 200 steps with cumulative reward -200.0
# Episode 583 finished after 130 steps with cumulative reward -130.0
# Episode 584 finished after 200 steps with cumulative reward -200.0
# Episode 585 finished after 200 steps with cumulative reward -200.0
# Episode 586 finished after 200 steps with cumulative reward -200.0
# Episode 587 finished after 161 steps with cumulative reward -161.0
# Episode 588 finished after 172 steps with cumulative reward -172.0
# Episode 589 finished after 146 steps with cumulative reward -146.0
# Episode 590 finished after 200 steps with cumulative reward -200.0
# Episode 591 finished after 199 steps with cumulative reward -199.0
# Episode 592 finished after 197 steps with cumulative reward -197.0
# Episode 593 finished after 152 steps with cumulative reward -152.0
# Episode 594 finished after 115 steps with cumulative reward -115.0
# Episode 595 finished after 150 steps with cumulative reward -150.0
# Episode 596 finished after 142 steps with cumulative reward -142.0
# Episode 597 finished after 124 steps with cumulative reward -124.0
# Episode 598 finished after 193 steps with cumulative reward -193.0
# Episode 599 finished after 200 steps with cumulative reward -200.0
# Episode 600 finished after 180 steps with cumulative reward -180.0
# Episode 601 finished after 200 steps with cumulative reward -200.0
# Episode 602 finished after 200 steps with cumulative reward -200.0
# Episode 603 finished after 152 steps with cumulative reward -152.0
# Episode 604 finished after 183 steps with cumulative reward -183.0
# Episode 605 finished after 200 steps with cumulative reward -200.0
# Episode 606 finished after 132 steps with cumulative reward -132.0
# Episode 607 finished after 144 steps with cumulative reward -144.0
# Episode 608 finished after 157 steps with cumulative reward -157.0
# Episode 609 finished after 200 steps with cumulative reward -200.0
# Episode 610 finished after 185 steps with cumulative reward -185.0
# Episode 611 finished after 200 steps with cumulative reward -200.0
# Episode 612 finished after 147 steps with cumulative reward -147.0
# Episode 613 finished after 150 steps with cumulative reward -150.0
# Episode 614 finished after 186 steps with cumulative reward -186.0
# Episode 615 finished after 199 steps with cumulative reward -199.0
# Episode 616 finished after 200 steps with cumulative reward -200.0
# Episode 617 finished after 184 steps with cumulative reward -184.0
# Episode 618 finished after 200 steps with cumulative reward -200.0
# Episode 619 finished after 199 steps with cumulative reward -199.0
# Episode 620 finished after 148 steps with cumulative reward -148.0
# Episode 621 finished after 131 steps with cumulative reward -131.0
# Episode 622 finished after 174 steps with cumulative reward -174.0
# Episode 623 finished after 143 steps with cumulative reward -143.0
# Episode 624 finished after 200 steps with cumulative reward -200.0
# Episode 625 finished after 199 steps with cumulative reward -199.0
# Episode 626 finished after 144 steps with cumulative reward -144.0
# Episode 627 finished after 200 steps with cumulative reward -200.0
# Episode 628 finished after 97 steps with cumulative reward -97.0
# Episode 629 finished after 149 steps with cumulative reward -149.0
# Episode 630 finished after 184 steps with cumulative reward -184.0
# Episode 631 finished after 200 steps with cumulative reward -200.0
# Episode 632 finished after 200 steps with cumulative reward -200.0
# Episode 633 finished after 189 steps with cumulative reward -189.0
# Episode 634 finished after 147 steps with cumulative reward -147.0
# Episode 635 finished after 104 steps with cumulative reward -104.0
# Episode 636 finished after 158 steps with cumulative reward -158.0
# Episode 637 finished after 135 steps with cumulative reward -135.0
# Episode 638 finished after 200 steps with cumulative reward -200.0
# Episode 639 finished after 142 steps with cumulative reward -142.0
# Episode 640 finished after 150 steps with cumulative reward -150.0
# Episode 641 finished after 184 steps with cumulative reward -184.0
# Episode 642 finished after 154 steps with cumulative reward -154.0
# Episode 643 finished after 151 steps with cumulative reward -151.0
# Episode 644 finished after 177 steps with cumulative reward -177.0
# Episode 645 finished after 165 steps with cumulative reward -165.0
# Episode 646 finished after 159 steps with cumulative reward -159.0
# Episode 647 finished after 164 steps with cumulative reward -164.0
# Episode 648 finished after 200 steps with cumulative reward -200.0
# Episode 649 finished after 153 steps with cumulative reward -153.0
# Episode 650 finished after 139 steps with cumulative reward -139.0
# Episode 651 finished after 200 steps with cumulative reward -200.0
# Episode 652 finished after 167 steps with cumulative reward -167.0
# Episode 653 finished after 200 steps with cumulative reward -200.0
# Episode 654 finished after 200 steps with cumulative reward -200.0
# Episode 655 finished after 200 steps with cumulative reward -200.0
# Episode 656 finished after 149 steps with cumulative reward -149.0
# Episode 657 finished after 95 steps with cumulative reward -95.0
# Episode 658 finished after 200 steps with cumulative reward -200.0
# Episode 659 finished after 168 steps with cumulative reward -168.0
# Episode 660 finished after 158 steps with cumulative reward -158.0
# Episode 661 finished after 200 steps with cumulative reward -200.0
# Episode 662 finished after 200 steps with cumulative reward -200.0
# Episode 663 finished after 200 steps with cumulative reward -200.0
# Episode 664 finished after 200 steps with cumulative reward -200.0
# Episode 665 finished after 200 steps with cumulative reward -200.0
# Episode 666 finished after 200 steps with cumulative reward -200.0
# Episode 667 finished after 200 steps with cumulative reward -200.0
# Episode 668 finished after 162 steps with cumulative reward -162.0
# Episode 669 finished after 200 steps with cumulative reward -200.0
# Episode 670 finished after 200 steps with cumulative reward -200.0
# Episode 671 finished after 200 steps with cumulative reward -200.0
# Episode 672 finished after 200 steps with cumulative reward -200.0
# Episode 673 finished after 200 steps with cumulative reward -200.0
# Episode 674 finished after 200 steps with cumulative reward -200.0
# Episode 675 finished after 200 steps with cumulative reward -200.0
# Episode 676 finished after 200 steps with cumulative reward -200.0
# Episode 677 finished after 200 steps with cumulative reward -200.0
# Episode 678 finished after 200 steps with cumulative reward -200.0
# Episode 679 finished after 200 steps with cumulative reward -200.0
# Episode 680 finished after 200 steps with cumulative reward -200.0
# Episode 681 finished after 200 steps with cumulative reward -200.0
# Episode 682 finished after 200 steps with cumulative reward -200.0
# Episode 683 finished after 200 steps with cumulative reward -200.0
# Episode 684 finished after 200 steps with cumulative reward -200.0
# Episode 685 finished after 200 steps with cumulative reward -200.0
# Episode 686 finished after 200 steps with cumulative reward -200.0
# Episode 687 finished after 200 steps with cumulative reward -200.0
# Episode 688 finished after 200 steps with cumulative reward -200.0
# Episode 689 finished after 200 steps with cumulative reward -200.0
# Episode 690 finished after 200 steps with cumulative reward -200.0
# Episode 691 finished after 200 steps with cumulative reward -200.0
# Episode 692 finished after 200 steps with cumulative reward -200.0
# Episode 693 finished after 200 steps with cumulative reward -200.0
# Episode 694 finished after 181 steps with cumulative reward -181.0
# Episode 695 finished after 200 steps with cumulative reward -200.0
# Episode 696 finished after 200 steps with cumulative reward -200.0
# Episode 697 finished after 200 steps with cumulative reward -200.0
# Episode 698 finished after 157 steps with cumulative reward -157.0
# Episode 699 finished after 200 steps with cumulative reward -200.0
# Episode 700 finished after 199 steps with cumulative reward -199.0
# Episode 701 finished after 113 steps with cumulative reward -113.0
# Episode 702 finished after 187 steps with cumulative reward -187.0
# Episode 703 finished after 157 steps with cumulative reward -157.0
# Episode 704 finished after 200 steps with cumulative reward -200.0
# Episode 705 finished after 173 steps with cumulative reward -173.0
# Episode 706 finished after 200 steps with cumulative reward -200.0
# Episode 707 finished after 177 steps with cumulative reward -177.0
# Episode 708 finished after 187 steps with cumulative reward -187.0
# Episode 709 finished after 176 steps with cumulative reward -176.0
# Episode 710 finished after 200 steps with cumulative reward -200.0
# Episode 711 finished after 127 steps with cumulative reward -127.0
# Episode 712 finished after 171 steps with cumulative reward -171.0
# ...
# Episode 2264 finished after 173 steps with cumulative reward -173.0
# Episode 2265 finished after 134 steps with cumulative reward -134.0
# Episode 2266 finished after 113 steps with cumulative reward -113.0
# Episode 2267 finished after 135 steps with cumulative reward -135.0
# Episode 2268 finished after 139 steps with cumulative reward -139.0
# Episode 2269 finished after 126 steps with cumulative reward -126.0
# Episode 2270 finished after 155 steps with cumulative reward -155.0
# Episode 2271 finished after 163 steps with cumulative reward -163.0
# Episode 2272 finished after 134 steps with cumulative reward -134.0
# Episode 2273 finished after 139 steps with cumulative reward -139.0
# Episode 2274 finished after 168 steps with cumulative reward -168.0
# Episode 2275 finished after 85 steps with cumulative reward -85.0
# Episode 2276 finished after 132 steps with cumulative reward -132.0
# Episode 2277 finished after 84 steps with cumulative reward -84.0
# Episode 2278 finished after 136 steps with cumulative reward -136.0
# Episode 2279 finished after 136 steps with cumulative reward -136.0
# Episode 2280 finished after 138 steps with cumulative reward -138.0
# Episode 2281 finished after 132 steps with cumulative reward -132.0
# Episode 2282 finished after 136 steps with cumulative reward -136.0
# Episode 2283 finished after 135 steps with cumulative reward -135.0
# Episode 2284 finished after 133 steps with cumulative reward -133.0
# Episode 2285 finished after 188 steps with cumulative reward -188.0
# Episode 2286 finished after 155 steps with cumulative reward -155.0
# Episode 2287 finished after 193 steps with cumulative reward -193.0
# Episode 2288 finished after 132 steps with cumulative reward -132.0
# Episode 2289 finished after 132 steps with cumulative reward -132.0
# Episode 2290 finished after 149 steps with cumulative reward -149.0
# Episode 2291 finished after 189 steps with cumulative reward -189.0
# Episode 2292 finished after 200 steps with cumulative reward -200.0
# Episode 2293 finished after 200 steps with cumulative reward -200.0
# Episode 2294 finished after 134 steps with cumulative reward -134.0
# Episode 2295 finished after 134 steps with cumulative reward -134.0
# Episode 2296 finished after 131 steps with cumulative reward -131.0
# Episode 2297 finished after 134 steps with cumulative reward -134.0
# Episode 2298 finished after 133 steps with cumulative reward -133.0
# Episode 2299 finished after 146 steps with cumulative reward -146.0
# Episode 2300 finished after 84 steps with cumulative reward -84.0
# Episode 2301 finished after 135 steps with cumulative reward -135.0
# Episode 2302 finished after 154 steps with cumulative reward -154.0
# Episode 2303 finished after 132 steps with cumulative reward -132.0
# Episode 2304 finished after 84 steps with cumulative reward -84.0
# Episode 2305 finished after 150 steps with cumulative reward -150.0
# Episode 2306 finished after 84 steps with cumulative reward -84.0
# Episode 2307 finished after 172 steps with cumulative reward -172.0
# Episode 2308 finished after 88 steps with cumulative reward -88.0
# Episode 2309 finished after 146 steps with cumulative reward -146.0
# Episode 2310 finished after 156 steps with cumulative reward -156.0
# Episode 2311 finished after 139 steps with cumulative reward -139.0
# Episode 2312 finished after 131 steps with cumulative reward -131.0
# Episode 2313 finished after 128 steps with cumulative reward -128.0
# Episode 2314 finished after 167 steps with cumulative reward -167.0
# Episode 2315 finished after 105 steps with cumulative reward -105.0
# Episode 2316 finished after 87 steps with cumulative reward -87.0
# Episode 2317 finished after 89 steps with cumulative reward -89.0
# Episode 2318 finished after 132 steps with cumulative reward -132.0
# Episode 2319 finished after 152 steps with cumulative reward -152.0
# Episode 2320 finished after 157 steps with cumulative reward -157.0
# Episode 2321 finished after 178 steps with cumulative reward -178.0
# Episode 2322 finished after 133 steps with cumulative reward -133.0
# Episode 2323 finished after 147 steps with cumulative reward -147.0
# Episode 2324 finished after 89 steps with cumulative reward -89.0
# Episode 2325 finished after 87 steps with cumulative reward -87.0
# Episode 2326 finished after 86 steps with cumulative reward -86.0
# Episode 2327 finished after 135 steps with cumulative reward -135.0
# Episode 2328 finished after 84 steps with cumulative reward -84.0
# Episode 2329 finished after 132 steps with cumulative reward -132.0
# Episode 2330 finished after 131 steps with cumulative reward -131.0
# Episode 2331 finished after 86 steps with cumulative reward -86.0
# Episode 2332 finished after 159 steps with cumulative reward -159.0
# Episode 2333 finished after 130 steps with cumulative reward -130.0
# Episode 2334 finished after 91 steps with cumulative reward -91.0
# Episode 2335 finished after 140 steps with cumulative reward -140.0
# Episode 2336 finished after 192 steps with cumulative reward -192.0
# Episode 2337 finished after 140 steps with cumulative reward -140.0
# Episode 2338 finished after 146 steps with cumulative reward -146.0
# Episode 2339 finished after 129 steps with cumulative reward -129.0
# Episode 2340 finished after 152 steps with cumulative reward -152.0
# Episode 2341 finished after 131 steps with cumulative reward -131.0
# Episode 2342 finished after 137 steps with cumulative reward -137.0
# Episode 2343 finished after 135 steps with cumulative reward -135.0
# Episode 2344 finished after 133 steps with cumulative reward -133.0
# Episode 2345 finished after 132 steps with cumulative reward -132.0
# Episode 2346 finished after 164 steps with cumulative reward -164.0
# Episode 2347 finished after 157 steps with cumulative reward -157.0
# Episode 2348 finished after 145 steps with cumulative reward -145.0
# Episode 2349 finished after 109 steps with cumulative reward -109.0
# Episode 2350 finished after 139 steps with cumulative reward -139.0
# Episode 2351 finished after 133 steps with cumulative reward -133.0
# Episode 2352 finished after 137 steps with cumulative reward -137.0
# Episode 2353 finished after 142 steps with cumulative reward -142.0
# Episode 2354 finished after 157 steps with cumulative reward -157.0
# Episode 2355 finished after 189 steps with cumulative reward -189.0
# Episode 2356 finished after 110 steps with cumulative reward -110.0
# Episode 2357 finished after 107 steps with cumulative reward -107.0
# Episode 2358 finished after 87 steps with cumulative reward -87.0
# Episode 2359 finished after 200 steps with cumulative reward -200.0
# Episode 2360 finished after 133 steps with cumulative reward -133.0
# Episode 2361 finished after 143 steps with cumulative reward -143.0
# Episode 2362 finished after 130 steps with cumulative reward -130.0
# Episode 2363 finished after 193 steps with cumulative reward -193.0
# Episode 2364 finished after 84 steps with cumulative reward -84.0
# Episode 2365 finished after 136 steps with cumulative reward -136.0
# Episode 2366 finished after 111 steps with cumulative reward -111.0
# Episode 2367 finished after 151 steps with cumulative reward -151.0
# Episode 2368 finished after 160 steps with cumulative reward -160.0
# Episode 2369 finished after 121 steps with cumulative reward -121.0
# Episode 2370 finished after 126 steps with cumulative reward -126.0
# Episode 2371 finished after 137 steps with cumulative reward -137.0
# Episode 2372 finished after 89 steps with cumulative reward -89.0
# Episode 2373 finished after 138 steps with cumulative reward -138.0
# Episode 2374 finished after 133 steps with cumulative reward -133.0
# Episode 2375 finished after 170 steps with cumulative reward -170.0
# Episode 2376 finished after 165 steps with cumulative reward -165.0
# Episode 2377 finished after 119 steps with cumulative reward -119.0
# Episode 2378 finished after 115 steps with cumulative reward -115.0
# Episode 2379 finished after 135 steps with cumulative reward -135.0
# Episode 2380 finished after 106 steps with cumulative reward -106.0
# Episode 2381 finished after 146 steps with cumulative reward -146.0
# Episode 2382 finished after 135 steps with cumulative reward -135.0
# Episode 2383 finished after 141 steps with cumulative reward -141.0
# Episode 2384 finished after 87 steps with cumulative reward -87.0
# Episode 2385 finished after 137 steps with cumulative reward -137.0
# Episode 2386 finished after 199 steps with cumulative reward -199.0
# Episode 2387 finished after 146 steps with cumulative reward -146.0
# Episode 2388 finished after 159 steps with cumulative reward -159.0
# Episode 2389 finished after 147 steps with cumulative reward -147.0
# Episode 2390 finished after 134 steps with cumulative reward -134.0
# Episode 2391 finished after 101 steps with cumulative reward -101.0
# Episode 2392 finished after 93 steps with cumulative reward -93.0
# Episode 2393 finished after 129 steps with cumulative reward -129.0
# Episode 2394 finished after 151 steps with cumulative reward -151.0
# Episode 2395 finished after 143 steps with cumulative reward -143.0
# Episode 2396 finished after 164 steps with cumulative reward -164.0
# Episode 2397 finished after 145 steps with cumulative reward -145.0
# Episode 2398 finished after 169 steps with cumulative reward -169.0
# Episode 2399 finished after 95 steps with cumulative reward -95.0
# Episode 2400 finished after 96 steps with cumulative reward -96.0
# Episode 2401 finished after 160 steps with cumulative reward -160.0
# Episode 2402 finished after 147 steps with cumulative reward -147.0
# Episode 2403 finished after 150 steps with cumulative reward -150.0
# Episode 2404 finished after 151 steps with cumulative reward -151.0
# Episode 2405 finished after 140 steps with cumulative reward -140.0
# Episode 2406 finished after 156 steps with cumulative reward -156.0
# Episode 2407 finished after 91 steps with cumulative reward -91.0
# Episode 2408 finished after 144 steps with cumulative reward -144.0
# Episode 2409 finished after 145 steps with cumulative reward -145.0
# Episode 2410 finished after 140 steps with cumulative reward -140.0
# Episode 2411 finished after 170 steps with cumulative reward -170.0
# Episode 2412 finished after 147 steps with cumulative reward -147.0
# Episode 2413 finished after 145 steps with cumulative reward -145.0
# Episode 2414 finished after 85 steps with cumulative reward -85.0
# Episode 2415 finished after 146 steps with cumulative reward -146.0
# Episode 2416 finished after 146 steps with cumulative reward -146.0
# Episode 2417 finished after 150 steps with cumulative reward -150.0
# Episode 2418 finished after 152 steps with cumulative reward -152.0
# Episode 2419 finished after 200 steps with cumulative reward -200.0
# Episode 2420 finished after 152 steps with cumulative reward -152.0
# Episode 2421 finished after 189 steps with cumulative reward -189.0
# Episode 2422 finished after 164 steps with cumulative reward -164.0
# Episode 2423 finished after 159 steps with cumulative reward -159.0
# Episode 2424 finished after 153 steps with cumulative reward -153.0
# Episode 2425 finished after 86 steps with cumulative reward -86.0
# Episode 2426 finished after 86 steps with cumulative reward -86.0
# Episode 2427 finished after 182 steps with cumulative reward -182.0
# Episode 2428 finished after 84 steps with cumulative reward -84.0
# Episode 2429 finished after 85 steps with cumulative reward -85.0
# Episode 2430 finished after 200 steps with cumulative reward -200.0
# Episode 2431 finished after 187 steps with cumulative reward -187.0
# Episode 2432 finished after 84 steps with cumulative reward -84.0
# Episode 2433 finished after 89 steps with cumulative reward -89.0
# Episode 2434 finished after 143 steps with cumulative reward -143.0
# Episode 2435 finished after 100 steps with cumulative reward -100.0
# Episode 2436 finished after 152 steps with cumulative reward -152.0
# Episode 2437 finished after 169 steps with cumulative reward -169.0
# Episode 2438 finished after 165 steps with cumulative reward -165.0
# Episode 2439 finished after 170 steps with cumulative reward -170.0
# Episode 2440 finished after 160 steps with cumulative reward -160.0
# Episode 2441 finished after 87 steps with cumulative reward -87.0
# Episode 2442 finished after 85 steps with cumulative reward -85.0
# Episode 2443 finished after 90 steps with cumulative reward -90.0
# Episode 2444 finished after 144 steps with cumulative reward -144.0
# Episode 2445 finished after 154 steps with cumulative reward -154.0
# Episode 2446 finished after 142 steps with cumulative reward -142.0
# Episode 2447 finished after 149 steps with cumulative reward -149.0
# Episode 2448 finished after 148 steps with cumulative reward -148.0
# Episode 2449 finished after 102 steps with cumulative reward -102.0
# Episode 2450 finished after 155 steps with cumulative reward -155.0
# Episode 2451 finished after 110 steps with cumulative reward -110.0
# Episode 2452 finished after 147 steps with cumulative reward -147.0
# Episode 2453 finished after 93 steps with cumulative reward -93.0
# Episode 2454 finished after 84 steps with cumulative reward -84.0
# Episode 2455 finished after 144 steps with cumulative reward -144.0
# Episode 2456 finished after 165 steps with cumulative reward -165.0
# Episode 2457 finished after 163 steps with cumulative reward -163.0
# Episode 2458 finished after 87 steps with cumulative reward -87.0
# Episode 2459 finished after 88 steps with cumulative reward -88.0
# Episode 2460 finished after 152 steps with cumulative reward -152.0
# Episode 2461 finished after 95 steps with cumulative reward -95.0
# Episode 2462 finished after 171 steps with cumulative reward -171.0
# Episode 2463 finished after 156 steps with cumulative reward -156.0
# Episode 2464 finished after 158 steps with cumulative reward -158.0
# Episode 2465 finished after 175 steps with cumulative reward -175.0
# Episode 2466 finished after 153 steps with cumulative reward -153.0
# Episode 2467 finished after 95 steps with cumulative reward -95.0
# Episode 2468 finished after 151 steps with cumulative reward -151.0
# Episode 2469 finished after 173 steps with cumulative reward -173.0
# Episode 2470 finished after 88 steps with cumulative reward -88.0
# Episode 2471 finished after 85 steps with cumulative reward -85.0
# Episode 2472 finished after 152 steps with cumulative reward -152.0
# Episode 2473 finished after 151 steps with cumulative reward -151.0
# Episode 2474 finished after 166 steps with cumulative reward -166.0
# Episode 2475 finished after 87 steps with cumulative reward -87.0
# Episode 2476 finished after 153 steps with cumulative reward -153.0
# Episode 2477 finished after 108 steps with cumulative reward -108.0
# Episode 2478 finished after 97 steps with cumulative reward -97.0
# Episode 2479 finished after 101 steps with cumulative reward -101.0
# Episode 2480 finished after 90 steps with cumulative reward -90.0
# Episode 2481 finished after 84 steps with cumulative reward -84.0
# Episode 2482 finished after 87 steps with cumulative reward -87.0
# Episode 2483 finished after 89 steps with cumulative reward -89.0
# Episode 2484 finished after 143 steps with cumulative reward -143.0
# Episode 2485 finished after 163 steps with cumulative reward -163.0
# Episode 2486 finished after 142 steps with cumulative reward -142.0
# Episode 2487 finished after 107 steps with cumulative reward -107.0
# Episode 2488 finished after 86 steps with cumulative reward -86.0
# Episode 2489 finished after 178 steps with cumulative reward -178.0
# Episode 2490 finished after 148 steps with cumulative reward -148.0
# Episode 2491 finished after 122 steps with cumulative reward -122.0
# Episode 2492 finished after 169 steps with cumulative reward -169.0
# Episode 2493 finished after 86 steps with cumulative reward -86.0
# Episode 2494 finished after 114 steps with cumulative reward -114.0
# Episode 2495 finished after 177 steps with cumulative reward -177.0
# Episode 2496 finished after 181 steps with cumulative reward -181.0
# Episode 2497 finished after 147 steps with cumulative reward -147.0
# Episode 2498 finished after 85 steps with cumulative reward -85.0
# Episode 2499 finished after 178 steps with cumulative reward -178.0
# Model saved to dqn_model1.pth

# %% [markdown]
# # Testing
#
# After training, the model is tested and evaluated. The test involves running the agent in the environment and calculating metrics like the number of successes, failures, average reward, and more.

# %%
class DQNAgentTest:
    def __init__(self, env, model_path):
        self.env = env
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        self.model = create_network(env.observation_space.shape[0], env.action_space.n).to(self.device)
        self.model.load_state_dict(torch.load(model_path, map_location=self.device))
        self.model.eval()

    def select_action(self, state):
        state = torch.FloatTensor(state).unsqueeze(0).to(self.device)
        with torch.no_grad():
            q_values = self.model(state)
        return q_values.cpu().numpy().argmax()

    def test(self, num_episodes=10):
        total_rewards = 0
        successes = 0
        total_steps = 0
        failures = 0

        for episode in range(num_episodes):
            state, _ = self.env.reset(seed=episode)
            cumulative_reward = 0
            done = False
            steps = 0

            while not done:
                self.env.render()
                action = self.select_action(state)
                next_state, reward, terminated, truncated, _ = self.env.step(action)
                state = next_state
                cumulative_reward += reward
                steps += 1
                done = terminated or truncated

                # Consider failure if the car doesn't reach the goal within 200 steps
                if steps >= 200:
                    failures += 1
                    break

            total_rewards += cumulative_reward
            total_steps += steps
            if cumulative_reward > -200:  # Assuming reward of -200 means failure in this environment
                successes += 1

            print(f"Test Episode {episode} finished with cumulative reward {cumulative_reward} in {steps} steps.")

        average_reward = total_rewards / num_episodes
        success_rate = (successes / num_episodes) * 100
        average_steps = total_steps / num_episodes

        print(f"\nEvaluation Metrics over {num_episodes} episodes:")
        print(f"Average Reward: {average_reward}")
        print(f"Success Rate: {success_rate}%")
        print(f"Average Steps to Completion: {average_steps}")
        print(f"Failures: {failures}")

# Path to the saved model
model_path = "Moutain_Car_DQN_Model.pth"

# Create the test agent and load the trained model
test_agent = DQNAgentTest(env, model_path)

# Run the test and evaluate
test_agent.test(num_episodes=10)
# Out:
# C:\Users\abhay\AppData\Local\Temp\ipykernel_27044\1126434634.py:7: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(model_path, map_location=self.device))
# Test Episode 0 finished with cumulative reward -149.0 in 149 steps.
# Test Episode 1 finished with cumulative reward -142.0 in 142 steps.
# Test Episode 2 finished with cumulative reward -162.0 in 162 steps.
# Test Episode 3 finished with cumulative reward -114.0 in 114 steps.
# Test Episode 4 finished with cumulative reward -84.0 in 84 steps.
# Test Episode 5 finished with cumulative reward -89.0 in 89 steps.
# Test Episode 6 finished with cumulative reward -145.0 in 145 steps.
# Test Episode 7 finished with cumulative reward -148.0 in 148 steps.
# Test Episode 8 finished with cumulative reward -161.0 in 161 steps.
# Test Episode 9 finished with cumulative reward -86.0 in 86 steps.
#
# Evaluation Metrics over 10 episodes:
# Average Reward: -128.0
# Success Rate: 100.0%
# Average Steps to Completion: 128.0
# Failures: 0
